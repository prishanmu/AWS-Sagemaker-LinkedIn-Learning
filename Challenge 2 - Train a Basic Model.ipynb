# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import os
import sys
import time
import json
from IPython.display import display
from time import strftime, gmtime
import sagemaker
from sagemaker.predictor import csv_serializer

# %%
#connect to s3 bucket

bucket = 'sagemaker-exercises'
prefix = 'sagemaker/DEMO-xgboost'

# Define IAM role
import boto3
import re
from sagemaker import get_execution_role

role = get_execution_role()

# %%
churn = pd.read_csv('./Data sets/churn.txt')
pd.set_option('display.max_columns', 500)
churn.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# 0             25     265.1        110       45.07     197.4         99
# 1             26     161.6        123       27.47     195.5        103
# 2              0     243.4        114       41.38     121.2        110
# 3              0     299.4         71       50.90      61.9         88
# 4              0     166.7        113       28.34     148.3        122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 0       16.78       244.7           91         11.01       10.0           3
# 1       16.62       254.4          103         11.45       13.7           3
# 2       10.30       162.6          104          7.32       12.2           5
# 3        5.26       196.9           89          8.86        6.6           7
# 4       12.61       186.9          121          8.41       10.1           3
#
#    Intl Charge  CustServ Calls  Churn?
# 0         2.70               1  False.
# 1         3.70               1  False.
# 2         3.29               0  False.
# 3         1.78               2  False.
# 4         2.73               3  False.

# %%
#clean up df
churn = churn.drop('Phone', axis=1)
churn['Area Code'] = churn['Area Code'].astype(object)
churn = churn.drop(['Day Charge', 'Eve Charge', 'Night Charge', 'Intl Charge'], axis=1)

# %%
#one hot encode
model_data = pd.get_dummies(churn)
model_data = pd.concat([model_data['Churn?_True.'], model_data.drop(['Churn?_False.', 'Churn?_True.'], axis=1)], axis=1)

# %%
model_data.shape
# Out:
# (3333, 70)

# %%
# train-validation-test split
train_data, validation_data, test_data = np.split(model_data.sample(frac=1, random_state=1729), [int(0.7 * len(model_data)), int(0.9 * len(model_data))])
train_data.to_csv('train.csv', header=False, index=False)
validation_data.to_csv('validation.csv', header=False, index=False)

# %%
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')).upload_file('validation.csv')

# %% [markdown]
# ### create and train a logistic regression model

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(boto3.Session().region_name, 'linear-learner') # image is named linear-learner for logistic regression
# Out:
# WARNING:sagemaker.amazon.amazon_estimator:'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.

# %%
s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket, prefix), content_type='text/csv')
s3_input_validation = sagemaker.s3_input(s3_data='s3://{}/{}/validation/'.format(bucket, prefix), content_type='text/csv')
# Out:
# WARNING:sagemaker:'s3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# WARNING:sagemaker:'s3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
sess = sagemaker.Session()

lr = sagemaker.estimator.Estimator(container,
                                    role, 
                                    train_instance_count=1, 
                                    train_instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(bucket, prefix),
                                    sagemaker_session=sess)
# Out:
# WARNING:root:Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %%
#documentation: https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html

lr.set_hyperparameters(feature_dim= 69, 
                      epochs = 5, 
                      predictor_type = 'binary_classifier')

lr.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2020-07-10 18:55:09 Starting - Starting the training job...
# 2020-07-10 18:55:11 Starting - Launching requested ML instances......
# 2020-07-10 18:56:24 Starting - Preparing the instances for training......
# 2020-07-10 18:57:31 Downloading - Downloading input data...
# 2020-07-10 18:57:56 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
#

#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6913793981970251, "sum": 0.6913793981970251, "min": 0.6913793981970251}}, "EndTime": 1594407499.892333, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594407499.892315}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.43034019126548423, "sum": 0.43034019126548423, "min": 0.43034019126548423}}, "EndTime": 1594407499.892407, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594407499.892388}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4318615795971753, "sum": 0.4318615795971753, "min": 0.4318615795971753}}, "EndTime": 1594407499.892482, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594407499.892463}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.42189222914320573, "sum": 0.42189222914320573, "min": 0.42189222914320573}}, "EndTime": 1594407499.89254, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594407499.892527}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.42213687381228887, "sum": 0.42213687381228887, "min": 0.42213687381228887}}, "EndTime": 1594407499.892574, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594407499.892566}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6732439837298235, "sum": 0.6732439837298235, "min": 0.6732439837298235}}, "EndTime": 1594407499.892638, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594407499.89262}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6820286931218328, "sum": 0.6820286931218328, "min": 0.6820286931218328}}, "EndTime": 1594407499.892711, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594407499.892692}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6673726949605856, "sum": 0.6673726949605856, "min": 0.6673726949605856}}, "EndTime": 1594407499.892781, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594407499.892764}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6797628316793356, "sum": 0.6797628316793356, "min": 0.6797628316793356}}, "EndTime": 1594407499.892854, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594407499.892835}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.46512803086289417, "sum": 0.46512803086289417, "min": 0.46512803086289417}}, "EndTime": 1594407499.892918, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594407499.892901}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4570142957899306, "sum": 0.4570142957899306, "min": 0.4570142957899306}}, "EndTime": 1594407499.892991, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594407499.892974}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.44213344814541106, "sum": 0.44213344814541106, "min": 0.44213344814541106}}, "EndTime": 1594407499.893059, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594407499.893042}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.46653229767853793, "sum": 0.46653229767853793, "min": 0.46653229767853793}}, "EndTime": 1594407499.893123, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594407499.893106}
#
# [07/10/2020 18:58:19 INFO 140560395855680] #quality_metric: host=algo-1, epoch=0, validation binary_classification_cross_entropy_objective <loss>=0.652341138135
# [07/10/2020 18:58:19 INFO 140560395855680] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=sampled_accuracy, value=0.851351351351
# [07/10/2020 18:58:19 INFO 140560395855680] Epoch 0: Loss improved. Updating best model
# [07/10/2020 18:58:19 INFO 140560395855680] Saving model for epoch: 0
# [07/10/2020 18:58:19 INFO 140560395855680] Saved checkpoint to "/tmp/tmp5DNkUE/mx-mod-0000.params"
# [07/10/2020 18:58:19 INFO 140560395855680] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Batches Since Last Reset": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Records Since Last Reset": {"count": 1, "max": 2333, "sum": 2333.0, "min": 2333}, "Total Batches Seen": {"count": 1, "max": 7, "sum": 7.0, "min": 7}, "Total Records Seen": {"count": 1, "max": 5666, "sum": 5666.0, "min": 5666}, "Max Records Seen Between Resets": {"count": 1, "max": 2333, "sum": 2333.0, "min": 2333}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1594407499.903495, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594407499.407677}
#
# [07/10/2020 18:58:19 INFO 140560395855680] #throughput_metric: host=algo-1, train throughput=4704.39739331 records/second
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6432855529785156, "sum": 0.6432855529785156, "min": 0.6432855529785156}}, "EndTime": 1594407500.002175, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594407500.002107}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6686128540039062, "sum": 0.6686128540039062, "min": 0.6686128540039062}}, "EndTime": 1594407500.002255, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594407500.002242}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6628607482910156, "sum": 0.6628607482910156, "min": 0.6628607482910156}}, "EndTime": 1594407500.002327, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594407500.002309}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6553686218261718, "sum": 0.6553686218261718, "min": 0.6553686218261718}}, "EndTime": 1594407500.002397, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594407500.002378}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3306248779296875, "sum": 0.3306248779296875, "min": 0.3306248779296875}}, "EndTime": 1594407500.002462, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594407500
#progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Batches Since Last Reset": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Records Since Last Reset": {"count": 1, "max": 2333, "sum": 2333.0, "min": 2333}, "Total Batches Seen": {"count": 1, "max": 19, "sum": 19.0, "min": 19}, "Total Records Seen": {"count": 1, "max": 14998, "sum": 14998.0, "min": 14998}, "Max Records Seen Between Resets": {"count": 1, "max": 2333, "sum": 2333.0, "min": 2333}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1594407502.288882, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1594407501.678634}
#
# [07/10/2020 18:58:22 INFO 140560395855680] #throughput_metric: host=algo-1, train throughput=3822.14085108 records/second
# [07/10/2020 18:58:22 WARNING 140560395855680] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [07/10/2020 18:58:22 WARNING 140560395855680] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [07/10/2020 18:58:22 INFO 140560395855680] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=sampled_accuracy, value=0.857357357357
# [07/10/2020 18:58:22 INFO 140560395855680] Epoch 4: Loss improved. Updating best model
# [07/10/2020 18:58:22 INFO 140560395855680] #validation_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.4842542585309919)
# [07/10/2020 18:58:22 INFO 140560395855680] #validation_score (algo-1) : ('binary_classification_accuracy', 0.8588588588588588)
# [07/10/2020 18:58:22 INFO 140560395855680] #validation_score (algo-1) : ('binary_f_1.000', 0.38961038961038963)
# [07/10/2020 18:58:22 INFO 140560395855680] #validation_score (algo-1) : ('precision', 0.6818181818181818)
# [07/10/2020 18:58:22 INFO 140560395855680] #validation_score (algo-1) : ('recall', 0.2727272727272727)
# [07/10/2020 18:58:22 INFO 140560395855680] #quality_metric: host=algo-1, validation binary_classification_cross_entropy_objective <loss>=0.484254258531
# [07/10/2020 18:58:22 INFO 140560395855680] #quality_metric: host=algo-1, validation binary_classification_accuracy <score>=0.858858858859
# [07/10/2020 18:58:22 INFO 140560395855680] #quality_metric: host=algo-1, validation binary_f_1.000 <score>=0.38961038961
# [07/10/2020 18:58:22 INFO 140560395855680] #quality_metric: host=algo-1, validation precision <score>=0.681818181818
# [07/10/2020 18:58:22 INFO 140560395855680] #quality_metric: host=algo-1, validation recall <score>=0.272727272727
# [07/10/2020 18:58:22 INFO 140560395855680] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [07/10/2020 18:58:22 INFO 140560395855680] Saved checkpoint to "/tmp/tmpsdxvlq/mx-mod-0000.params"
# [07/10/2020 18:58:22 INFO 140560395855680] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 3556.5109252929688, "sum": 3556.5109252929688, "min": 3556.5109252929688}, "finalize.time": {"count": 1, "max": 402.9278755187988, "sum": 402.9278755187988, "min": 402.9278755187988}, "initialize.time": {"count": 1, "max": 183.22014808654785, "sum": 183.22014808654785, "min": 183.22014808654785}, "check_early_stopping.time": {"count": 6, "max": 1.2898445129394531, "sum": 6.73222541809082, "min": 0.9481906890869141}, "setuptime": {"count": 1, "max": 25.892972946166992, "sum": 25.892972946166992, "min": 25.892972946166992}, "update.time": {"count": 5, "max": 706.2671184539795, "sum": 2858.731269836426, "min": 471.68803215026855}, "epochs": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1594407502.697432, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1594407499.223896}
# 2020-07-10 18:58:34 Uploading - Uploading generated training model
# 2020-07-10 18:58:34 Completed - Training job completed
# Training seconds: 63
# Billable seconds: 63
